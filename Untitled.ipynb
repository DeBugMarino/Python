# %%
# import libraries 

from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
    "Accept-Encoding": "gzip, deflate",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
    "DNT": "1",
    "Connection": "close",
    "Upgrade-Insecure-Requests": "1"
}

try:
    page = requests.get(URL, headers=headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

    title = soup2.find(id='productTitle').get_text().strip()
    price = soup2.find(id='priceblock_ourprice')
    
    if price:
        price = price.get_text().strip()
    else:
        price = "Price not found"

    print("Title:", title)
    print("Price:", price)

except Exception as e:
    print("An error occurred:", e)
# Out:
# Title: Funny Got Data MIS Data Systems Business Analyst T-Shirt
# Price: Price not found

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # To run Chrome in headless mode

# Set up Selenium service
s = Service(ChromeDriverManager().install())

# Create a new instance of the Chrome driver
driver = webdriver.Chrome(service=s, options=chrome_options)

URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

# Load the page
driver.get(URL)

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Find the title
title = soup.find(id='productTitle').get_text().strip()

# Find the price
price_element = soup.find(id='priceblock_ourprice')
if price_element:
    price = price_element.get_text().strip()
else:
    price = "Price not found"

# Close the browser
driver.quit()

print("Title:", title)
print("Price:", price)
# Out:
# Title: Funny Got Data MIS Data Systems Business Analyst T-Shirt
# Price: Price not found

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# Set up Chrome options
chrome_options = Options()
chrome_options.add_argument("--headless")  # To run Chrome in headless mode

# Set up Selenium service
s = Service(ChromeDriverManager().install())

# Create a new instance of the Chrome driver
driver = webdriver.Chrome(service=s, options=chrome_options)

URL = 'https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data%2Banalyst%2Btshirt&qid=1626655184&sr=8-3&customId=B0752XJYNL&th=1'

# Load the page
driver.get(URL)

# Parse the HTML with BeautifulSoup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Find the title
title = soup.find(id='productTitle').get_text().strip()

# Find the price using different attributes
price_element = soup.find("span", {"class": "a-size-medium a-color-price priceBlockBuyingPriceString"})
if price_element:
    price = price_element.get_text().strip()
else:
    price = "Price not found"

# Close the browser
driver.quit()

print("Title:", title)
print("Price:", price)
# Out:
# Title: Funny Got Data MIS Data Systems Business Analyst T-Shirt
# Price: Price not found

# %%
import requests
from bs4 import BeautifulSoup
import time

def check_price():
    URL = 'https://www.amazon.it/adidas-IC9274-T-Shirt-Black-Uomo/dp/B0BSVG5G7K/ref=sr_1_3_sspa?dib=eyJ2IjoiMSJ9.u1LaAUTYa1KBxsAoyNreRb2wND0RLTZExJpT7w1mRRr3T_OSw86N2T-eiwk6dPv53H3zrMs9HxpEGkybaHkbLtx1mf_EcUQ7weZ9Cv9U7Ycc51C30O3iqFOgaBxw64VYJXDstBQ-zdYpMcUzvPrqFqXZpq_l-bGXbYYPuDk0QQquaaFk5gnEzH3znGJwl1DVjvP-YLxV2Jj8Dozs2l7fMLmJXHI0PVvkwhM65Dl7gYwHwf_SEBvf3no8y8CiBxKHeTDEk3y5Z8DvyTors3sSxPSICQbdcD7GBx30l5M8Uac._AMEuBQyk0UpqSKVwGs7wEgId_VLbQdAV_bu3NUT25I&dib_tag=se&keywords=t-shirt&qid=1711099428&sr=8-3-spons&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&psc=1'

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
        "Accept-Encoding": "gzip, deflate",
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8",
        "DNT": "1",
        "Connection": "close",
        "Upgrade-Insecure-Requests": "1"
    }

    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content, "html.parser")

    title_element = soup.find(id='productTitle')
    price_element = soup.find(id='priceblock_ourprice')

    if title_element:
        title = title_element.get_text().strip()
        print("Title:", title)
    else:
        print("Title not found.")

    if price_element:
        price = price_element.get_text().strip()[1:]  # Remove leading whitespace and currency symbol
        print("Price:", price)
    else:
        print("Price not found.")

# Runs check_price after a set time
while True:
    check_price()
    time.sleep(86400)  # Sleep for 24 hours
# Out:
# Title: ADIDAS IC9274 T-Shirt, Black, 3XL Uomo
# Price not found.
